# %% [markdown]
# #**Carga de datos, almacenamiento y formatos de archivo**

# %%
from google.colab import drive
drive.mount("/content/drive")

import sys
sys.path.append("/content/drive/MyDrive/utils")

from colab_git import setup, push

setup(
    project_dir="/content/drive/MyDrive/Colab Notebooks/Libro_Python_para_analisis_de_datos",
    repo="data_analyst",
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Repositorio listo: https://github.com/tuliobast/data_analyst.git

# %%
push('Comenzando capitulo 6')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2460/909772328.py in <cell line: 0>()
# ----> 1 push('Comenzando capitulo 6')
#
# NameError: name 'push' is not defined
